# %% [markdown]
# #XAI und Visualisierung
#
# **visualisation.py**: Erstellt val_loss_comparison_by_version.png und test_loss_comparison_by_version.png welche in Gridsearchresult sind und die Ergebnisse verdeutlichen.

# %% [markdown]
# ![test_loss_comparison_by_version.png](data:image/png;base64,...)

# %% [markdown]
# Wir sehen, dass eine niedrige Learning Rate, tanh_norm als Normalisierungsstrategie, ein tiefes Netzwerk und viel Dropout generell sind.

# %% [markdown]
# **group.py**: Betrachtet nur welche Gruppe für die Prediction am wichtigsten ist durch Feature Ablation. Ähnlich wie Ablation Outputs aber nutzt explizit das neue Gruppenfeature.
#
# **fAblation.py**: Erstellt eine Feature Ablation Heatmap und zeigt auf welche Feature am wichtigsten sind. Hier allerdings noch ohne exakte Namen. Die Datei ist zudem outdated und wir vermutlich nicht mehr ohne Anpassungen funktionieren. Der Vollständigkeit halber habe ich sie aber drinnen gelassen.

# %% [markdown]
# ![ablation_summary.png](data:image/png;base64,...)

# %% [markdown]
# **shap2.py**: Vergleicht den Shap der einzelnen Gruppen (Ergebnis sehr klein also wahrscheinlich nicht aussagekräftig) und erstellt eine Heatmap sowie Summary.

# %% [markdown]
# ![shap_summary.png](data:image/png;base64,...)

# %% [markdown]
# ![shap_grouped_bar.png](data:image/png;base64,...)

# %% [markdown]
# **dnn.py**: Zuletzt wollte ich testen ob ein dnn also mit 20 Layers und nicht nur 2-3 vlt etwas bringt. Allerdings hat dieses nicht besser bzw sogarÄschlechter funktioniert. Im Ordner ist auch eine Visulalisierung vorhanden, welche allerdings nicht sehr aussagekräftig ist. Das File selbst ist mittlerweile outdated, da der Ansatz nicht zielführend war.
#
# **metrics.py**: Vergleicht unser Modell mit verschiedensten Metriken aus dem Paper gegen das Paper und erzielt ähnliche aber nicht die gleichen Ergebnisse

# %% [markdown]
# ###Standard libraries
# os,
# gzip,
# pickle,
# random,
# from collections import defaultdict,
# ast
#
# ###Numerical and scientific libraries
# numpy,
# pandas,
# matplotlib.pyplot,
# seaborn
#
# ###PyTorch
# torch,
# torch.nn,
# from torch.utils.data import DataLoader, TensorDataset
#
# ###Machine learning / evaluation
# from sklearn.metrics import root_mean_squared_error, mean_squared_error
#
# ###Model and data modules
# from model import Encoder, load_model,
# from grid_search import SynergyDataModule
#
# ###Explainability / feature attribution
# import shap,
# from captum.attr import FeatureAblation
